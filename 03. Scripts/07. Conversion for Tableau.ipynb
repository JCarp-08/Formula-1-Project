# %% [markdown]
# # Converting Data to CSV for Tableau
# ## 01. Import Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 02. Data

# %%
df = pd.read_pickle(r"C:\Users\jmanc\OneDrive\Desktop\F1 Project\Data\Prepped Data\race_lap_full.pkl")
df.head(10)
# Out:
#    resultId  raceId  driverId  constructorId  number  grid  position  \
# 0     22131     900       825              1      20     4       2.0
# 1     22131     900       825              1      20     4       2.0
# 2     22131     900       825              1      20     4       2.0
# 3     22131     900       825              1      20     4       2.0
# 4     22131     900       825              1      20     4       2.0
# 5     22131     900       825              1      20     4       2.0
# 6     22131     900       825              1      20     4       2.0
# 7     22131     900       825              1      20     4       2.0
# 8     22131     900       825              1      20     4       2.0
# 9     22131     900       825              1      20     4       2.0
#
#   positionText  positionOrder  points  ...  code  forename    surname  \
# 0            2              2    18.0  ...   MAG     Kevin  Magnussen
# ...

# %%
df.shape
# Out:
# (206419, 31)

# %% [markdown]
# ## 03. Export to CSV

# %%
df.to_csv(r"C:\Users\jmanc\OneDrive\Desktop\F1 Project\Data\Prepped Data\race_lap_full.csv")
